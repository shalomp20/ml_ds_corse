# %%
print("hi")
# Out:
# hi

# %%
import pandas as pd 
df = pd.read_csv('https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv')

# %%
import pandas as pd
import numpy as np 

import seaborn as sns 
from matplotlib import pyplot as plt 
# %matplotlib inline

# %%
df =  pd.read_csv('data.csv')
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
len(df)
# Out:
# 11914

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

string_columns = list(df.dtypes[df.dtypes == 'object'].index)

for col in string_columns:
    df[col] = df[col].str.lower().str.replace(' ', '_')

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway_mpg  city_mpg  popularity   msrp
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
plt.figure(figsize=(6, 4))

sns.histplot(df.msrp[df.msrp < 100000], bins=60, color='black', alpha=1)
plt.ylabel('Frequency')
plt.xlabel('Price')
plt.title('Distribution of prices')

plt.show()

# %%
df.isnull().sum()
# Out:
# make                    0
# model                   0
# year                    0
# engine_fuel_type        3
# engine_hp              69
# engine_cylinders       30
# transmission_type       0
# driven_wheels           0
# number_of_doors         6
# market_category      3742
# vehicle_size            0
# vehicle_style           0
# highway_mpg             0
# city_mpg                0
# popularity              0
# msrp                    0
# dtype: int64

# %%
n= len(df)
n_val = int(n*0.2)
n_test = int(n*0.2)
n_train = n - n_val - n_test

n , n_val + n_test + n_train
# Out:
# (11914, 11914)

# %%
idx = np.arange(n)
np.random.seed(2)   
np.random.shuffle(idx)

# %%
df_val = df.iloc[idx[:n_val]]
df_test = df.iloc[idx[n_val:n_val+n_test]]
df_train = df.iloc[idx[n_val + n_test:]]
print(n_val)
df_val
# Out:
# 2382
#                 make           model  year                engine_fuel_type  \
# 2735       Chevrolet          Cobalt  2008                regular unleaded
# 6720          Toyota          Matrix  2012                regular unleaded
# 5878          Subaru         Impreza  2016                regular unleaded
# 11190     Volkswagen         Vanagon  1991                regular unleaded
# 4554            Ford           F-150  2017        flex-fuel (unleaded/E85)
# ...              ...             ...   ...                             ...
# 7773        Infiniti             Q50  2015  premium unleaded (recommended)
# 9509       Chevrolet  Silverado 1500  2015        flex-fuel (unleaded/E85)
# 4682            Ford          Fiesta  2016                regular unleaded
# 3701   Mercedes-Benz         E-Class  2016     premium unleaded (required)
# 3454           Dodge          Dakota  2009                regular unleaded
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 2735       148.0               4.0            MANUAL  front wheel drive
# 6720       132.0               4.0         AUTOMATIC  front wheel drive
# 5878       148.0               4.0         AUTOMATIC    all wheel drive
# 11190       90.0               4.0            MANUAL   rear wheel drive
# 4554       385.0               8.0         AUTOMATIC   four wheel drive
# ...          ...               ...               ...                ...
# 7773       328.0               6.0         AUTOMATIC    all wheel drive
# 9509       285.0               6.0         AUTOMATIC   four wheel drive
# 4682       197.0               4.0            MANUAL  front wheel drive
# 3701       302.0               6.0         AUTOMATIC    all wheel drive
# 3454       210.0               6.0            MANUAL   rear wheel drive
#
#        number_of_doors                      market_category vehicle_size  \
# 2735               2.0                                  NaN      Compact
# 6720               4.0                            Hatchback      Compact
# 5878               4.0                            Hatchback      Compact
# 11190              3.0                                  NaN        Large
# 4554               4.0                            Flex Fuel        Large
# ...                ...                                  ...          ...
# 7773               4.0              Luxury,High-Performance      Midsize
# 9509               2.0                            Flex Fuel        Large
# 4682               4.0  Hatchback,Factory Tuner,Performance      Compact
# 3701               4.0                   Luxury,Performance      Midsize
# 3454               4.0                            Flex Fuel      Compact
#
#             vehicle_style  highway_mpg  city_mpg  popularity   msrp
# 2735                Coupe           33        24        1385  14410
# 6720        4dr Hatchback           32        25        2031  19685
# 5878        4dr Hatchback           37        28         640  19795
# 11190   Passenger Minivan           18        16         873   2000
# 4554      Crew Cab Pickup           21        15        5657  56260
# ...                   ...          ...       ...         ...    ...
# 7773                Sedan           27        19         190  45450
# 9509   Regular Cab Pickup           22        17        1385  32095
# 4682        4dr Hatchback           32        26        5657  21460
# 3701                Sedan           28        20         617  55600
# 3454      Crew Cab Pickup           20        16        1851  25260
#
# [2382 rows x 16 columns]

# %%
df_train.head()
# Out:
#           make     model  year                engine_fuel_type  engine_hp  \
# 8597       Kia     Rondo  2008                regular unleaded      162.0
# 6408    Subaru    Legacy  2016                regular unleaded      175.0
# 11241  Hyundai  Veloster  2016                regular unleaded      132.0
# 569       FIAT       500  2017  premium unleaded (recommended)      101.0
# 1659   Lincoln   Aviator  2005     premium unleaded (required)      302.0
#
#        engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 8597                4.0         AUTOMATIC  front wheel drive              4.0
# 6408                4.0         AUTOMATIC    all wheel drive              4.0
# 11241               4.0            MANUAL  front wheel drive              3.0
# 569                 4.0         AUTOMATIC  front wheel drive              2.0
# 1659                8.0         AUTOMATIC    all wheel drive              4.0
#
#       market_category vehicle_size  vehicle_style  highway_mpg  city_mpg  \
# 8597              NaN      Compact          Wagon           26        19
# 6408              NaN      Midsize          Sedan           36        26
# 11241       Hatchback      Compact  2dr Hatchback           35        27
# 569         Hatchback      Compact  2dr Hatchback           33        27
# 1659           Luxury      Midsize        4dr SUV           16        11
#
#        popularity   msrp
# 8597         1720  16395
# 6408          640  24145
# 11241        1439  18000
# 569           819  15990
# 1659           61  43585

# %%
len(df) ,len(df_train) + len(df_val) + len(df_test)
# Out:
# (11914, 11914)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
df_train , len(df_train)
# Out:
# (           make         model  year                engine_fuel_type  \
#  0           Kia         Rondo  2008                regular unleaded
#  1        Subaru        Legacy  2016                regular unleaded
#  2       Hyundai      Veloster  2016                regular unleaded
#  3          FIAT           500  2017  premium unleaded (recommended)
#  4       Lincoln       Aviator  2005     premium unleaded (required)
#  ...         ...           ...   ...                             ...
#  7145  Chevrolet     Chevy Van  1998                regular unleaded
#  7146     Subaru  XV Crosstrek  2014                regular unleaded
#  7147      Dodge        Magnum  2006                regular unleaded
#  7148      Honda         Civic  2016                regular unleaded
#  7149     Subaru       Outback  2015                regular unleaded
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
#  0         162.0               4.0         AUTOMATIC  front wheel drive
#  1         175.0               4.0         AUTOMATIC    all wheel drive
#  2         132.0               4.0            MANUAL  front wheel drive
#  3         101.0               4.0         AUTOMATIC  front wheel drive
#  4         302.0               8.0         AUTOMATIC    all wheel drive
#  ...         ...               ...               ...                ...
#  7145      200.0               6.0         AUTOMATIC   rear wheel drive
#  7146      160.0               4.0         AUTOMATIC    all wheel drive
#  7147      250.0               6.0         AUTOMATIC    all wheel drive
#  7148      174.0               4.0         AUTOMATIC  front wheel drive
#  7149      256.0               6.0         AUTOMATIC    all wheel drive
#
#        number_of_doors   market_category vehicle_size  vehicle_style  \
#  0                 4.0               NaN      Compact          Wagon
#  1                 4.0               NaN      Midsize          Sedan
#  2                 3.0         Hatchback      Compact  2dr Hatchback
#  3                 2.0         Hatchback      Compact  2dr Hatchback
#  4                 4.0            Luxury      Midsize        4dr SUV
#  ...               ...               ...          ...            ...
#  7145              3.0               NaN      Midsize      Cargo Van
#  7146              4.0  Crossover,Hybrid      Compact        4dr SUV
#  7147              4.0               NaN        Large          Wagon
#  7148              4.0               NaN      Midsize          Sedan
#  7149              4.0         Crossover      Midsize        4dr SUV
#
#        highway_mpg  city_mpg  popularity   msrp
#  0              26        19        1720  16395
#  1              36        26         640  24145
#  2              35        27        1439  18000
#  3              33        27         819  15990
#  4              16        11          61  43585
#  ...           ...       ...         ...    ...
#  7145           18        13        1385   2052
#  7146           33        29         640  25995
#  7147           22        15        1851  29100
#  7148           42        31        2202  22200
#  7149           27        20         640  32995
#
#  [7150 rows x 16 columns],
#  7150)

# %%
y_train =np.log1p(df_train.msrp.values)
y_val = np.log1p(df_val.msrp.values)
y_test = np.log1p(df_test.msrp.values)
print(y_train)
# Out:
# [ 9.70479268 10.09187401  9.79818259 ... 10.27852782 10.00789261
#  10.40414162]

# %%
del df_train['msrp']
del df_val['msrp']
del df_test['msrp']

# %%
df_train
# Out:
#            make         model  year                engine_fuel_type  \
# 0           Kia         Rondo  2008                regular unleaded
# 1        Subaru        Legacy  2016                regular unleaded
# 2       Hyundai      Veloster  2016                regular unleaded
# 3          FIAT           500  2017  premium unleaded (recommended)
# 4       Lincoln       Aviator  2005     premium unleaded (required)
# ...         ...           ...   ...                             ...
# 7145  Chevrolet     Chevy Van  1998                regular unleaded
# 7146     Subaru  XV Crosstrek  2014                regular unleaded
# 7147      Dodge        Magnum  2006                regular unleaded
# 7148      Honda         Civic  2016                regular unleaded
# 7149     Subaru       Outback  2015                regular unleaded
#
#       engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 0         162.0               4.0         AUTOMATIC  front wheel drive
# 1         175.0               4.0         AUTOMATIC    all wheel drive
# 2         132.0               4.0            MANUAL  front wheel drive
# 3         101.0               4.0         AUTOMATIC  front wheel drive
# 4         302.0               8.0         AUTOMATIC    all wheel drive
# ...         ...               ...               ...                ...
# 7145      200.0               6.0         AUTOMATIC   rear wheel drive
# 7146      160.0               4.0         AUTOMATIC    all wheel drive
# 7147      250.0               6.0         AUTOMATIC    all wheel drive
# 7148      174.0               4.0         AUTOMATIC  front wheel drive
# 7149      256.0               6.0         AUTOMATIC    all wheel drive
#
#       number_of_doors   market_category vehicle_size  vehicle_style  \
# 0                 4.0               NaN      Compact          Wagon
# 1                 4.0               NaN      Midsize          Sedan
# 2                 3.0         Hatchback      Compact  2dr Hatchback
# 3                 2.0         Hatchback      Compact  2dr Hatchback
# 4                 4.0            Luxury      Midsize        4dr SUV
# ...               ...               ...          ...            ...
# 7145              3.0               NaN      Midsize      Cargo Van
# 7146              4.0  Crossover,Hybrid      Compact        4dr SUV
# 7147              4.0               NaN        Large          Wagon
# 7148              4.0               NaN      Midsize          Sedan
# 7149              4.0         Crossover      Midsize        4dr SUV
#
#       highway_mpg  city_mpg  popularity
# 0              26        19        1720
# 1              36        26         640
# 2              35        27        1439
# 3              33        27         819
# 4              16        11          61
# ...           ...       ...         ...
# 7145           18        13        1385
# 7146           33        29         640
# 7147           22        15        1851
# 7148           42        31        2202
# 7149           27        20         640
#
# [7150 rows x 15 columns]
